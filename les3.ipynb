# %% [markdown]
# ## Задача 1
# Даны значения зарплат из выборки выпускников:
# 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 230, 24, 57, 55, 70, 75, 65, 84, 90, 150
#
# Используя только встроенные питоновские функции и структуры данных (т.е. без библиотек numpy, pandas и др.), посчитайте (несмещённое) среднее квадратичное отклонение для данной выборки.

# %%
salary = [100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 230, 24, 57, 55, 70, 75, 65, 84, 90, 150]
X = sum(salary) / len(salary)       # Выборочное среднее

# %%
sum_ = 0
for i in salary:              # Считаю сумму квадратов разностией элементов и среднего
    sum_ += (i - X) ** 2
round((sum_ / (len(salary) - 1)) ** (1/2), 8)        # Вычисляю корень по формуле и ограничиваю число знаков до 8
# Out:
# 47.34795214

# %% [markdown]
# ## Задача 2
# Найдите число выбросов в выборке из задачи 1. Для определения выбросов используйте методику как при построении “усов” в boxplot, однако, как и в задаче 1, пользоваться можно только встроенными функциями и структурами данных.

# %%
salary = sorted(salary)     # Сортируем по возрастанию
len(salary) % 4             # Проверяем на делимость на 4
# Out:
# 1

# %%
q1 = salary[len(salary) // 4]     # Находим квантиль 0,25
q3 = salary[3 * len(salary) // 4]      # # Находим квантиль 0,75
q1, q3
# Out:
# (45, 84)

# %%
iqr = q3 - q1 
range_1 = (q1 - 1.5 * iqr) # Находим границы выбросов
range_2 = (q3 + 1.5 * iqr)

# %%
counter = 0
for i in salary:           # Считаем кол-во выбросов
    if i <= range_1 or i >= range_2:
        counter += 1
print(f'Число выбросов в выборке равно: {counter}')
# Out:
# Число выбросов в выборке равно: 2

# %% [markdown]
# ## Задача 3
# В университет на факультет A поступило 100 человек, на факультет B - 90 человек и на факультет C - 45 человек. Вероятность того, что студент с факультета A сдаст первую сессию, равна 0.6. Для студента с факультета B эта вероятность равна 0.7, а для студента с факультета C - 0.8. Случайным образом выбирается студент, сдавший первую сессию. Какое событие наиболее вероятно:
#
# студент учится на факультете A,
#
# студент учится на факультете B,
#
# студент учится на факультете C?
#
# Замечание: да, эта задача не на тему статистики, но тема важная, и её стоит иногда освежать в памяти.

# %%
A = 100 / 235
B = 90 / 235
C = 45 / 235

# %%
P_A = 0.6
P_B = 0.7
P_C = 0.8

# %% [markdown]
# Необходимо найти полную вероятность P_F:

# %%
P_F = P_A * A + P_B * B + P_C * C
P_F
# Out:
# 0.676595744680851

# %% [markdown]
# По формуле Байеса вычислим вероятности учебы случайно выбранного студента на факультетах:

# %%
A_PA = P_A * A / P_F
B_PB = P_B * B / P_F
C_PC = P_C * C / P_F
A_PA, B_PB, C_PC             # Ответ: 2
# Out:
# (0.3773584905660377, 0.39622641509433965, 0.22641509433962265)
